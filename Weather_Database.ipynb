# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# create random set of lat and long combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# create list of coordinates
coordinates = list(lats_lngs)

# create empty city list
cities = []

# get nearest city
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
cities
# Out:
# ['kaa-khem',
#  'abu samrah',
#  'faanui',
#  'lagoa',
#  'busselton',
#  'pisco',
#  'oxelosund',
#  'fort saint john',
#  'mar del plata',
#  'ushuaia',
#  'saskylakh',
#  'yellowknife',
#  'humboldt',
#  'punta arenas',
#  'port blair',
#  'khatanga',
#  'grand river south east',
#  'butaritari',
#  'acapulco',
#  'rikitea',
#  'longonjo',
#  'ust-tsilma',
#  'prieska',
#  'jacareacanga',
#  'zhezkazgan',
#  'esmeralda',
#  'saint george',
#  'avarua',
#  'camapua',
#  'padang',
#  'sao paulo de olivenca',
#  'palabuhanratu',
#  'atambua',
#  'lata',
#  'thompson',
#  'saint-philippe',
#  'barrow',
#  'kruisfontein',
#  'margate',
#  'tabuk',
#  'cape town',
#  'tiksi',
#  'hobart',
#  'samusu',
#  'camacha',
#  'boende',
#  'kodiak',
#  'tahta',
#  'atuona',
#  'nikolskoye',
#  'dingle',
#  'cap malheureux',
#  'husavik',
#  'belushya guba',
#  'port macquarie',
#  'mataura',
#  'hermanus',
#  'kijang',
#  'port alfred',
#  'la ronge',
#  'vaini',
#  'ouesso',
#  'madrid',
#  'saldanha',
#  'norman wells',
#  'catamayo',
#  'bluff',
#  'puerto ayora',
#  'alofi',
#  'serra branca',
#  'dhola',
#  'bredasdorp',
#  'isiro',
#  'quatre cocos',
#  'tarko-sale',
#  'marion',
#  'santa catarina de tepehuanes',
#  'kavaratti',
#  'tilichiki',
#  'shubarshi',
#  'alice springs',
#  'kapaa',
#  'mys shmidta',
#  'adrar',
#  'hithadhoo',
#  'hobyo',
#  'sao filipe',
#  'new norfolk',
#  'katobu',
#  'wajima',
#  'tuatapere',
#  'taolanaro',
#  'ilulissat',
#  'pevek',
#  'sitka',
#  'nome',
#  'kaitangata',
#  'hilo',
#  'santander',
#  'uglegorsk',
#  'clyde river',
#  'tazovskiy',
#  'roma',
#  'lorengau',
#  'port antonio',
#  'arraial do cabo',
#  'lipin bor',
#  'nouadhibou',
#  'qaanaaq',
#  'portland',
#  'tasiilaq',
#  'calvia',
#  'green river',
#  'birnin kebbi',
#  'port elizabeth',
#  'albany',
#  'camacupa',
#  'talnakh',
#  'mount isa',
#  'coquimbo',
#  'nuuk',
#  'sorland',
#  'kalmunai',
#  'namibe',
#  'huarmey',
#  'sentyabrskiy',
#  'prince rupert',
#  'chokurdakh',
#  'soria',
#  'erdaojiang',
#  'artyk',
#  'narsaq',
#  'severo-kurilsk',
#  'bairiki',
#  'gambiran',
#  'carnarvon',
#  'kiruna',
#  'fortuna',
#  'natal',
#  'east london',
#  'labuhan',
#  'hamilton',
#  'san patricio',
#  'avera',
#  'uige',
#  'fairbanks',
#  'cidreira',
#  'castro',
#  'sechura',
#  'poum',
#  'sint michiel',
#  'dikson',
#  'chuy',
#  'asayita',
#  'leningradskiy',
#  'seoul',
#  'paamiut',
#  'vinkovci',
#  'praia da vitoria',
#  'tuktoyaktuk',
#  'niscemi',
#  'wufeng',
#  'mackay',
#  'bambous virieux',
#  'jamestown',
#  'salalah',
#  'faya',
#  'barentsburg',
#  'urumqi',
#  'atbasar',
#  'berlevag',
#  'guerrero negro',
#  'cherskiy',
#  'kibaya',
#  'preobrazheniye',
#  'illoqqortoormiut',
#  'oudtshoorn',
#  'aswan',
#  'vaitape',
#  'kieta',
#  'airai',
#  'shenjiamen',
#  'madimba',
#  'luderitz',
#  'oranjemund',
#  'saint-joseph',
#  'grindavik',
#  'suntar',
#  'sovetskiy',
#  'khandyga',
#  'nanortalik',
#  'coulihaut',
#  'himeji',
#  'klyuchi',
#  'huilong',
#  'manakara',
#  'georgetown',
#  'vila velha',
#  'urdzhar',
#  'katsuura',
#  'bethel',
#  'biritiba-mirim',
#  'mindelo',
#  'eenhana',
#  'yaan',
#  'nsanje',
#  'presidencia roque saenz pena',
#  'san carlos de bariloche',
#  'carutapera',
#  'gauripur',
#  'macusani',
#  'torbay',
#  'rawannawi',
#  'chimoio',
#  'kamenka',
#  'chapada dos guimaraes',
#  'xadani',
#  'aksarka',
#  'mahebourg',
#  'manyana',
#  'warrnambool',
#  'hokitika',
#  'cayenne',
#  'provideniya',
#  'saint-augustin',
#  'lae',
#  'chicama',
#  'mayumba',
#  'kousseri',
#  'chumikan',
#  'eirunepe',
#  'moose factory',
#  'lompoc',
#  'nova vicosa',
#  'taoudenni',
#  'barhi',
#  'kondinskoye',
#  'melfort',
#  'te anau',
#  'mashhad',
#  'tahe',
#  'byadgi',
#  'kaeo',
#  'daru',
#  'brae',
#  'klaksvik',
#  'amderma',
#  'victoria',
#  'nueva guinea',
#  'jalu',
#  'bongouanou',
#  'eyl',
#  'belyy yar',
#  'bongor',
#  'constitucion',
#  'aklavik',
#  'ballina',
#  'krasnyy yar',
#  'monrovia',
#  'naze',
#  'zabid',
#  'souillac',
#  'richards bay',
#  'sao lourenco do oeste',
#  'saleilua',
#  'polunochnoye',
#  'sicamous',
#  'wentzville',
#  'sola',
#  'batsfjord',
#  'sharan',
#  'chapais',
#  'gazli',
#  'ribeira grande',
#  'maryville',
#  'douglas',
#  'delta',
#  'nowy dwor gdanski',
#  'aksu',
#  'port lincoln',
#  'hazel crest',
#  'velizh',
#  'pasighat',
#  'benguela',
#  'longyearbyen',
#  'zhigansk',
#  'pangnirtung',
#  'sambava',
#  'flinders',
#  'cabo san lucas',
#  'halalo',
#  'grand gaube',
#  'qasigiannguit',
#  'sterlibashevo',
#  'puerto del rosario',
#  'hofn',
#  'vila franca do campo',
#  'taburi',
#  'panzhihua',
#  'sobolevo',
#  'okhotsk',
#  'mubi',
#  'namanga',
#  'penzance',
#  'nzerekore',
#  'camabatela',
#  'damghan',
#  'egvekinot',
#  'cabedelo',
#  'minudasht',
#  'phan rang',
#  'saleaula',
#  'shitanjing',
#  'carupano',
#  'sawakin',
#  'nelson bay',
#  'biltine',
#  'lewisporte',
#  'ponta do sol',
#  'gorin',
#  'porto novo',
#  'fasa',
#  'krasnoturinsk',
#  'fortuna foothills',
#  'nalut',
#  'namatanai',
#  'jinchang',
#  'moerai',
#  'san cristobal',
#  'arona',
#  'pontianak',
#  'samarai',
#  'komsomolskiy',
#  'kavieng',
#  'numaligarh',
#  'bria',
#  'zyryanka',
#  'walvis bay',
#  'marzuq',
#  'lazaro cardenas',
#  'ostrovnoy',
#  'londoko',
#  'ishigaki',
#  'ambilobe',
#  'atar',
#  'dunedin',
#  'condado',
#  'moroto',
#  'touros',
#  'indi',
#  'babstovo',
#  'karaul',
#  'kahului',
#  'lavrentiya',
#  'deputatskiy',
#  'tsihombe',
#  'itarema',
#  'kodinar',
#  'coihaique',
#  'nortelandia',
#  'hammerfest',
#  'puertollano',
#  'velikooktyabrskiy',
#  'lebu',
#  'shingu',
#  'pangai',
#  'isangel',
#  'kelvington',
#  'vung tau',
#  'caraballeda',
#  'blieskastel',
#  'nueva concepcion',
#  'george',
#  'vaitupu',
#  'reconquista',
#  'burgeo',
#  'byron bay',
#  'nampula',
#  'bilibino',
#  'jerantut',
#  'warqla',
#  'soyo',
#  'nianzishan',
#  'sai buri',
#  'tromso',
#  'barbacoas',
#  'kaili',
#  'of',
#  'keetmanshoop',
#  'saharsa',
#  'tura',
#  'bethanien',
#  'buon me thuot',
#  'hasaki',
#  'boffa',
#  'khonuu',
#  'maunabo',
#  'paris',
#  'mendoza',
#  'ha tinh',
#  'ayan',
#  'saint-pierre',
#  'churapcha',
#  'sao marcos',
#  'pierre',
#  'yuncheng',
#  'papara',
#  'conceicao do araguaia',
#  'nizhneyansk',
#  'conselheiro pena',
#  'blythe',
#  'baryatino',
#  'haines junction',
#  'bathsheba',
#  'olafsvik',
#  'bom jesus',
#  'southend-on-sea',
#  'ha giang',
#  'zalantun',
#  'morgan city',
#  'belle fourche',
#  'broken hill',
#  'magadan',
#  'upernavik',
#  'marsaxlokk',
#  'mahajanga',
#  'ketchikan',
#  'gazojak',
#  'coolum beach',
#  'kikwit',
#  'starotimoshkino',
#  'masuguru',
#  'muros',
#  'karamay',
#  'puerto maldonado',
#  'half moon bay',
#  'owen sound',
#  'skjervoy',
#  'tatawin',
#  'nogent-le-rotrou',
#  'plouzane',
#  'oskarshamn',
#  'qui nhon',
#  'roald',
#  'hovd',
#  'yialos',
#  'lebork',
#  'buqayq',
#  'raga',
#  'belmonte',
#  'gedzhukh',
#  'vestmannaeyjar',
#  'bahia honda',
#  'asgardstrand',
#  'sahrak',
#  'impfondo',
#  'kinablangan',
#  'yar-sale',
#  'sioux lookout',
#  'havoysund',
#  'hvide sande',
#  'sao joao da barra',
#  'mawlaik',
#  'ciupercenii noi',
#  'vardo',
#  'arrecife',
#  'byumba',
#  'awjilah',
#  'mongu',
#  'ossora',
#  'goya',
#  'curvelo',
#  'attawapiskat',
#  'lensk',
#  'bacuit',
#  'maldonado',
#  'tallahassee',
#  'yulara',
#  'vagur',
#  'pontal do parana',
#  'pennagaram',
#  'paita',
#  'sayyan',
#  'varzea da palma',
#  'pitimbu',
#  'rovnoye',
#  'rangapara',
#  'arlit',
#  'meulaboh',
#  'taltal',
#  'neuquen',
#  'obo',
#  'naryan-mar',
#  'esperance',
#  'westport',
#  'pilar',
#  'biloela',
#  'rudnichnyy',
#  'san lorenzo',
#  'iisalmi',
#  'talara',
#  'yerkoy',
#  'crab hill',
#  'kirksville',
#  'iqaluit',
#  'conceicao da barra',
#  'havre-saint-pierre',
#  'lawang',
#  'litovko',
#  'togur',
#  'russell',
#  'ust-kuyga',
#  'robinson',
#  'san quintin',
#  'high level',
#  'santa luzia',
#  'bereda',
#  'port moresby',
#  'belsand',
#  'emerald',
#  'omsukchan',
#  'sorvag',
#  'qarqin',
#  'ngukurr',
#  'ixtapa',
#  'ninghai',
#  'teknaf',
#  'conde',
#  'caravelas',
#  'nioro',
#  'zabaykalsk',
#  'bilma',
#  'stornoway',
#  'los llanos de aridane',
#  'toliary',
#  'satipo',
#  'praia',
#  'scottsbluff',
#  'bargal',
#  'platanos',
#  'olinda',
#  'masterton',
#  'karatau',
#  'kumbo',
#  'dzhebariki-khaya',
#  'zlitan',
#  'tezu',
#  'price',
#  'wencheng',
#  'west wendover',
#  'emmett',
#  'shimoda',
#  'hohhot',
#  'innellan',
#  'esterhazy',
#  'vostok',
#  'geraldton',
#  'yerbogachen',
#  'sao joao do piaui',
#  'bengkulu',
#  'pedernales',
#  'turukhansk',
#  'manuk mangkaw',
#  'college',
#  'usinsk',
#  'tumannyy',
#  'carndonagh',
#  'bolotnoye',
#  'waingapu',
#  'sur',
#  'ghanzi',
#  'clayton',
#  'bahia blanca',
#  'santa maria',
#  'homer',
#  'nishihara',
#  'bandarbeyla',
#  'moiyabana',
#  'ivanovka',
#  'udachnyy',
#  'welver',
#  'sabirabad',
#  'ivanava',
#  'tyler',
#  'beyneu',
#  'maniitsoq',
#  'kholodnyy',
#  'coleraine',
#  'taonan',
#  'rovaniemi',
#  'zeya',
#  'leh',
#  'stephenville',
#  'ialibu',
#  'maralal',
#  'bintulu',
#  'poso',
#  'springbok',
#  'tres arroyos',
#  'satitoa',
#  'vikulovo',
#  'pavlogradka',
#  'ariquemes',
#  'colares',
#  'altay',
#  'mezen',
#  'dunmore east',
#  'mayor pablo lagerenza',
#  'comodoro rivadavia',
#  'marsa matruh',
#  'christchurch',
#  'port hedland',
#  'yenotayevka',
#  'miro khan',
#  'lamar',
#  'road town',
#  'cockburn harbour',
#  'abu kamal',
#  'jabiru',
#  'mount gambier',
#  'huntsville',
#  'vao',
#  'coahuayana',
#  'lengshuitan',
#  'beloha',
#  'saryshagan',
#  'krasnoye',
#  'sug-aksy',
#  'kazachinskoye',
#  'black river',
#  'morehead',
#  'marquette',
#  'kayes',
#  'tabiauea',
#  'panelas',
#  'marawi',
#  'payo',
#  'vila',
#  'marienburg',
#  'kudahuvadhoo',
#  'marfino',
#  'jacmel',
#  'xai-xai',
#  'san policarpo',
#  'kadykchan',
#  'taybad',
#  'harper',
#  'nehe',
#  'mecca',
#  'sile',
#  'vysokogornyy',
#  'darnah',
#  'timizart',
#  'matay',
#  'ambagarh chauki',
#  'luebo',
#  'methoni',
#  'alvinopolis',
#  'bogorodskoye',
#  'sangar',
#  'rorvik',
#  'gaptsakh',
#  'abu zabad',
#  'makakilo city',
#  'temaraia',
#  'hambantota',
#  'belmopan',
#  'springdale',
#  'yashkul',
#  'san rafael',
#  'tambovka',
#  'gobabis',
#  'umba',
#  'griffith',
#  'pacific grove',
#  'ancud',
#  'karera',
#  'gornyy',
#  'henties bay',
#  'bonoua',
#  'codrington',
#  'beringovskiy',
#  'safakulevo',
#  'kirriemuir',
#  'sicuani',
#  'baykit',
#  'banda aceh',
#  'joaima',
#  'warrington',
#  'kemijarvi',
#  'auki',
#  'mersing',
#  'galveston',
#  'luancheng',
#  'aripuana',
#  'culiacan',
#  'bontang',
#  'severo-yeniseyskiy',
#  'maltahohe',
#  'cockburn town',
#  'champerico',
#  'longlac',
#  'kindu',
#  'vazante',
#  'onega',
#  'chimbote',
#  'lagodekhi',
#  'grass valley',
#  'teahupoo',
#  'kathmandu',
#  'tadine',
#  'mega',
#  'pervomayskoye',
#  'moradabad',
#  'thanh hoa',
#  'ugoofaaru',
#  'elizabeth city',
#  'anadyr',
#  'corund',
#  'bubaque',
#  'hurghada',
#  'joensuu',
#  'ranfurly',
#  'monastyrshchina',
#  'kargasok',
#  'noyabrsk',
#  'ruatoria',
#  'biankouma',
#  'north bend',
#  'kodinsk',
#  'tarudant',
#  'lakeside',
#  'na klang',
#  'labuan',
#  'sampit',
#  'erzin',
#  'manta',
#  'pavlovka',
#  'kuandian',
#  'aykhal',
#  'sabha',
#  'sibolga',
#  'buala',
#  'bartica',
#  'manono',
#  'darhan',
#  'andros town',
#  'oparino',
#  'micheweni',
#  'shizunai',
#  'karratha',
#  'coffs harbour',
#  'galiwinku']

# %%
# api call for openweathermap

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# create empty list for city data
city_data = []

# print the beginning of logging
print("Data Retrieval Has Begun")

# create counters
record_count = 1
set_count = 1

#loop through all cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count +=1
    #create endpoint URL
    city_url = url + "&q=" + city.replace(" ","+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count +=1
    # run API request for each city
    try:
        city_weather = requests.get(city_url).json()
        # pick needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # append info
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind_speed,
                          "Description": city_weather_desc})
        
    # if an error is experienced, skip city
    except:
        print("City not found. Skipping...")
        pass
    
print("***Data Retrieval Is Complete***")
# Out:
# Data Retrieval Has Begun
# Processing Record 1 of Set 1 | kaa-khem
# Processing Record 2 of Set 1 | abu samrah
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | pisco
# Processing Record 7 of Set 1 | oxelosund
# Processing Record 8 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | humboldt
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | port blair
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | acapulco
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | longonjo
# Processing Record 22 of Set 1 | ust-tsilma
# Processing Record 23 of Set 1 | prieska
# Processing Record 24 of Set 1 | jacareacanga
# Processing Record 25 of Set 1 | zhezkazgan
# Processing Record 26 of Set 1 | esmeralda
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | camapua
# Processing Record 30 of Set 1 | padang
# Processing Record 31 of Set 1 | sao paulo de olivenca
# Processing Record 32 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 1 | atambua
# Processing Record 34 of Set 1 | lata
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | margate
# Processing Record 40 of Set 1 | tabuk
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | camacha
# Processing Record 46 of Set 1 | boende
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | tahta
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 52 of Set 2 | dingle
# Processing Record 53 of Set 2 | cap malheureux
# Processing Record 54 of Set 2 | husavik
# Processing Record 55 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 56 of Set 2 | port macquarie
# Processing Record 57 of Set 2 | mataura
# Processing Record 58 of Set 2 | hermanus
# Processing Record 59 of Set 2 | kijang
# Processing Record 60 of Set 2 | port alfred
# Processing Record 61 of Set 2 | la ronge
# Processing Record 62 of Set 2 | vaini
# Processing Record 63 of Set 2 | ouesso
# Processing Record 64 of Set 2 | madrid
# Processing Record 65 of Set 2 | saldanha
# Processing Record 66 of Set 2 | norman wells
# Processing Record 67 of Set 2 | catamayo
# Processing Record 68 of Set 2 | bluff
# Processing Record 69 of Set 2 | puerto ayora
# Processing Record 70 of Set 2 | alofi
# Processing Record 71 of Set 2 | serra branca
# Processing Record 72 of Set 2 | dhola
# Processing Record 73 of Set 2 | bredasdorp
# Processing Record 74 of Set 2 | isiro
# Processing Record 75 of Set 2 | quatre cocos
# Processing Record 76 of Set 2 | tarko-sale
# Processing Record 77 of Set 2 | marion
# Processing Record 78 of Set 2 | santa catarina de tepehuanes
# Processing Record 79 of Set 2 | kavaratti
# Processing Record 80 of Set 2 | tilichiki
# Processing Record 81 of Set 2 | shubarshi
# Processing Record 82 of Set 2 | alice springs
# Processing Record 83 of Set 2 | kapaa
# Processing Record 84 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 85 of Set 2 | adrar
# Processing Record 86 of Set 2 | hithadhoo
# Processing Record 87 of Set 2 | hobyo
# Processing Record 88 of Set 2 | sao filipe
# Processing Record 89 of Set 2 | new norfolk
# Processing Record 90 of Set 2 | katobu
# Processing Record 91 of Set 2 | wajima
# Processing Record 92 of Set 2 | tuatapere
# Processing Record 93 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 94 of Set 2 | ilulissat
# Processing Record 95 of Set 2 | pevek
# Processing Record 96 of Set 2 | sitka
# Processing Record 97 of Set 2 | nome
# Processing Record 98 of Set 2 | kaitangata
# Processing Record 99 of Set 2 | hilo
# Processing Record 100 of Set 2 | santander
# Processing Record 101 of Set 2 | uglegorsk
# Processing Record 103 of Set 3 | clyde river
# Processing Record 104 of Set 3 | tazovskiy
# Processing Record 105 of Set 3 | roma
# Processing Record 106 of Set 3 | lorengau
# Processing Record 107 of Set 3 | port antonio
# Processing Record 108 of Set 3 | arraial do cabo
# Processing Record 109 of Set 3 | lipin bor
# Processing Record 110 of Set 3 | nouadhibou
# Processing Record 111 of Set 3 | qaanaaq
# Processing Record 112 of Set 3 | portland
# Processing Record 113 of Set 3 | tasiilaq
# Processing Record 114 of Set 3 | calvia
# Processing Record 115 of Set 3 | green river
# Processing Record 116 of Set 3 | birnin kebbi
# Processing Record 117 of Set 3 | port elizabeth
# Processing Record 118 of Set 3 | albany
# Processing Record 119 of Set 3 | camacupa
# Processing Record 120 of Set 3 | talnakh
# Processing Record 121 of Set 3 | mount isa
# Processing Record 122 of Set 3 | coquimbo
# Processing Record 123 of Set 3 | nuuk
# Processing Record 124 of Set 3 | sorland
# Processing Record 125 of Set 3 | kalmunai
# Processing Record 126 of Set 3 | namibe
# Processing Record 127 of Set 3 | huarmey
# Processing Record 128 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 129 of Set 3 | prince rupert
# Processing Record 130 of Set 3 | chokurdakh
# Processing Record 131 of Set 3 | soria
# Processing Record 132 of Set 3 | erdaojiang
# Processing Record 133 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 134 of Set 3 | narsaq
# Processing Record 135 of Set 3 | severo-kurilsk
# Processing Record 136 of Set 3 | bairiki
# Processing Record 137 of Set 3 | gambiran
# Processing Record 138 of Set 3 | carnarvon
# Processing Record 139 of Set 3 | kiruna
# Processing Record 140 of Set 3 | fortuna
# Processing Record 141 of Set 3 | natal
# Processing Record 142 of Set 3 | east london
# Processing Record 143 of Set 3 | labuhan
# Processing Record 144 of Set 3 | hamilton
# Processing Record 145 of Set 3 | san patricio
# Processing Record 146 of Set 3 | avera
# Processing Record 147 of Set 3 | uige
# Processing Record 148 of Set 3 | fairbanks
# Processing Record 149 of Set 3 | cidreira
# Processing Record 150 of Set 3 | castro
# Processing Record 151 of Set 3 | sechura
# Processing Record 152 of Set 3 | poum
# Processing Record 154 of Set 4 | sint michiel
# City not found. Skipping...
# Processing Record 155 of Set 4 | dikson
# Processing Record 156 of Set 4 | chuy
# Processing Record 157 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 158 of Set 4 | leningradskiy
# Processing Record 159 of Set 4 | seoul
# Processing Record 160 of Set 4 | paamiut
# Processing Record 161 of Set 4 | vinkovci
# Processing Record 162 of Set 4 | praia da vitoria
# Processing Record 163 of Set 4 | tuktoyaktuk
# Processing Record 164 of Set 4 | niscemi
# Processing Record 165 of Set 4 | wufeng
# Processing Record 166 of Set 4 | mackay
# Processing Record 167 of Set 4 | bambous virieux
# Processing Record 168 of Set 4 | jamestown
# Processing Record 169 of Set 4 | salalah
# Processing Record 170 of Set 4 | faya
# Processing Record 171 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 172 of Set 4 | urumqi
# Processing Record 173 of Set 4 | atbasar
# Processing Record 174 of Set 4 | berlevag
# Processing Record 175 of Set 4 | guerrero negro
# Processing Record 176 of Set 4 | cherskiy
# Processing Record 177 of Set 4 | kibaya
# Processing Record 178 of Set 4 | preobrazheniye
# Processing Record 179 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 180 of Set 4 | oudtshoorn
# Processing Record 181 of Set 4 | aswan
# Processing Record 182 of Set 4 | vaitape
# Processing Record 183 of Set 4 | kieta
# Processing Record 184 of Set 4 | airai
# Processing Record 185 of Set 4 | shenjiamen
# Processing Record 186 of Set 4 | madimba
# Processing Record 187 of Set 4 | luderitz
# Processing Record 188 of Set 4 | oranjemund
# Processing Record 189 of Set 4 | saint-joseph
# Processing Record 190 of Set 4 | grindavik
# Processing Record 191 of Set 4 | suntar
# Processing Record 192 of Set 4 | sovetskiy
# Processing Record 193 of Set 4 | khandyga
# Processing Record 194 of Set 4 | nanortalik
# Processing Record 195 of Set 4 | coulihaut
# City not found. Skipping...
# Processing Record 196 of Set 4 | himeji
# Processing Record 197 of Set 4 | klyuchi
# Processing Record 198 of Set 4 | huilong
# Processing Record 199 of Set 4 | manakara
# Processing Record 200 of Set 4 | georgetown
# Processing Record 201 of Set 4 | vila velha
# Processing Record 202 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 203 of Set 4 | katsuura
# Processing Record 205 of Set 5 | bethel
# Processing Record 206 of Set 5 | biritiba-mirim
# Processing Record 207 of Set 5 | mindelo
# Processing Record 208 of Set 5 | eenhana
# Processing Record 209 of Set 5 | yaan
# Processing Record 210 of Set 5 | nsanje
# Processing Record 211 of Set 5 | presidencia roque saenz pena
# Processing Record 212 of Set 5 | san carlos de bariloche
# Processing Record 213 of Set 5 | carutapera
# Processing Record 214 of Set 5 | gauripur
# Processing Record 215 of Set 5 | macusani
# Processing Record 216 of Set 5 | torbay
# Processing Record 217 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 218 of Set 5 | chimoio
# Processing Record 219 of Set 5 | kamenka
# Processing Record 220 of Set 5 | chapada dos guimaraes
# Processing Record 221 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 222 of Set 5 | aksarka
# Processing Record 223 of Set 5 | mahebourg
# Processing Record 224 of Set 5 | manyana
# Processing Record 225 of Set 5 | warrnambool
# Processing Record 226 of Set 5 | hokitika
# Processing Record 227 of Set 5 | cayenne
# Processing Record 228 of Set 5 | provideniya
# Processing Record 229 of Set 5 | saint-augustin
# Processing Record 230 of Set 5 | lae
# Processing Record 231 of Set 5 | chicama
# Processing Record 232 of Set 5 | mayumba
# Processing Record 233 of Set 5 | kousseri
# Processing Record 234 of Set 5 | chumikan
# Processing Record 235 of Set 5 | eirunepe
# Processing Record 236 of Set 5 | moose factory
# Processing Record 237 of Set 5 | lompoc
# Processing Record 238 of Set 5 | nova vicosa
# Processing Record 239 of Set 5 | taoudenni
# Processing Record 240 of Set 5 | barhi
# Processing Record 241 of Set 5 | kondinskoye
# Processing Record 242 of Set 5 | melfort
# Processing Record 243 of Set 5 | te anau
# Processing Record 244 of Set 5 | mashhad
# Processing Record 245 of Set 5 | tahe
# Processing Record 246 of Set 5 | byadgi
# Processing Record 247 of Set 5 | kaeo
# Processing Record 248 of Set 5 | daru
# Processing Record 249 of Set 5 | brae
# Processing Record 250 of Set 5 | klaksvik
# Processing Record 251 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 252 of Set 5 | victoria
# Processing Record 253 of Set 5 | nueva guinea
# Processing Record 254 of Set 5 | jalu
# Processing Record 256 of Set 6 | bongouanou
# Processing Record 257 of Set 6 | eyl
# Processing Record 258 of Set 6 | belyy yar
# Processing Record 259 of Set 6 | bongor
# Processing Record 260 of Set 6 | constitucion
# Processing Record 261 of Set 6 | aklavik
# Processing Record 262 of Set 6 | ballina
# Processing Record 263 of Set 6 | krasnyy yar
# Processing Record 264 of Set 6 | monrovia
# Processing Record 265 of Set 6 | naze
# Processing Record 266 of Set 6 | zabid
# Processing Record 267 of Set 6 | souillac
# Processing Record 268 of Set 6 | richards bay
# Processing Record 269 of Set 6 | sao lourenco do oeste
# Processing Record 270 of Set 6 | saleilua
# City not found. Skipping...
# Processing Record 271 of Set 6 | polunochnoye
# Processing Record 272 of Set 6 | sicamous
# Processing Record 273 of Set 6 | wentzville
# Processing Record 274 of Set 6 | sola
# Processing Record 275 of Set 6 | batsfjord
# Processing Record 276 of Set 6 | sharan
# Processing Record 277 of Set 6 | chapais
# Processing Record 278 of Set 6 | gazli
# Processing Record 279 of Set 6 | ribeira grande
# Processing Record 280 of Set 6 | maryville
# Processing Record 281 of Set 6 | douglas
# Processing Record 282 of Set 6 | delta
# Processing Record 283 of Set 6 | nowy dwor gdanski
# Processing Record 284 of Set 6 | aksu
# Processing Record 285 of Set 6 | port lincoln
# Processing Record 286 of Set 6 | hazel crest
# Processing Record 287 of Set 6 | velizh
# Processing Record 288 of Set 6 | pasighat
# Processing Record 289 of Set 6 | benguela
# Processing Record 290 of Set 6 | longyearbyen
# Processing Record 291 of Set 6 | zhigansk
# Processing Record 292 of Set 6 | pangnirtung
# Processing Record 293 of Set 6 | sambava
# Processing Record 294 of Set 6 | flinders
# Processing Record 295 of Set 6 | cabo san lucas
# Processing Record 296 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 297 of Set 6 | grand gaube
# Processing Record 298 of Set 6 | qasigiannguit
# Processing Record 299 of Set 6 | sterlibashevo
# Processing Record 300 of Set 6 | puerto del rosario
# Processing Record 301 of Set 6 | hofn
# Processing Record 302 of Set 6 | vila franca do campo
# Processing Record 303 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 304 of Set 6 | panzhihua
# Processing Record 305 of Set 6 | sobolevo
# Processing Record 307 of Set 7 | okhotsk
# Processing Record 308 of Set 7 | mubi
# Processing Record 309 of Set 7 | namanga
# Processing Record 310 of Set 7 | penzance
# Processing Record 311 of Set 7 | nzerekore
# Processing Record 312 of Set 7 | camabatela
# Processing Record 313 of Set 7 | damghan
# Processing Record 314 of Set 7 | egvekinot
# Processing Record 315 of Set 7 | cabedelo
# Processing Record 316 of Set 7 | minudasht
# Processing Record 317 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 318 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 319 of Set 7 | shitanjing
# Processing Record 320 of Set 7 | carupano
# Processing Record 321 of Set 7 | sawakin
# Processing Record 322 of Set 7 | nelson bay
# Processing Record 323 of Set 7 | biltine
# Processing Record 324 of Set 7 | lewisporte
# Processing Record 325 of Set 7 | ponta do sol
# Processing Record 326 of Set 7 | gorin
# Processing Record 327 of Set 7 | porto novo
# Processing Record 328 of Set 7 | fasa
# Processing Record 329 of Set 7 | krasnoturinsk
# Processing Record 330 of Set 7 | fortuna foothills
# Processing Record 331 of Set 7 | nalut
# Processing Record 332 of Set 7 | namatanai
# Processing Record 333 of Set 7 | jinchang
# Processing Record 334 of Set 7 | moerai
# Processing Record 335 of Set 7 | san cristobal
# Processing Record 336 of Set 7 | arona
# Processing Record 337 of Set 7 | pontianak
# Processing Record 338 of Set 7 | samarai
# Processing Record 339 of Set 7 | komsomolskiy
# Processing Record 340 of Set 7 | kavieng
# Processing Record 341 of Set 7 | numaligarh
# Processing Record 342 of Set 7 | bria
# Processing Record 343 of Set 7 | zyryanka
# Processing Record 344 of Set 7 | walvis bay
# Processing Record 345 of Set 7 | marzuq
# Processing Record 346 of Set 7 | lazaro cardenas
# Processing Record 347 of Set 7 | ostrovnoy
# Processing Record 348 of Set 7 | londoko
# Processing Record 349 of Set 7 | ishigaki
# Processing Record 350 of Set 7 | ambilobe
# Processing Record 351 of Set 7 | atar
# Processing Record 352 of Set 7 | dunedin
# Processing Record 353 of Set 7 | condado
# Processing Record 354 of Set 7 | moroto
# Processing Record 355 of Set 7 | touros
# Processing Record 356 of Set 7 | indi
# Processing Record 358 of Set 8 | babstovo
# Processing Record 359 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 360 of Set 8 | kahului
# Processing Record 361 of Set 8 | lavrentiya
# Processing Record 362 of Set 8 | deputatskiy
# Processing Record 363 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 364 of Set 8 | itarema
# Processing Record 365 of Set 8 | kodinar
# Processing Record 366 of Set 8 | coihaique
# Processing Record 367 of Set 8 | nortelandia
# Processing Record 368 of Set 8 | hammerfest
# Processing Record 369 of Set 8 | puertollano
# Processing Record 370 of Set 8 | velikooktyabrskiy
# Processing Record 371 of Set 8 | lebu
# Processing Record 372 of Set 8 | shingu
# Processing Record 373 of Set 8 | pangai
# Processing Record 374 of Set 8 | isangel
# Processing Record 375 of Set 8 | kelvington
# Processing Record 376 of Set 8 | vung tau
# Processing Record 377 of Set 8 | caraballeda
# Processing Record 378 of Set 8 | blieskastel
# Processing Record 379 of Set 8 | nueva concepcion
# Processing Record 380 of Set 8 | george
# Processing Record 381 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 382 of Set 8 | reconquista
# Processing Record 383 of Set 8 | burgeo
# Processing Record 384 of Set 8 | byron bay
# Processing Record 385 of Set 8 | nampula
# Processing Record 386 of Set 8 | bilibino
# Processing Record 387 of Set 8 | jerantut
# Processing Record 388 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 389 of Set 8 | soyo
# Processing Record 390 of Set 8 | nianzishan
# Processing Record 391 of Set 8 | sai buri
# Processing Record 392 of Set 8 | tromso
# Processing Record 393 of Set 8 | barbacoas
# Processing Record 394 of Set 8 | kaili
# Processing Record 395 of Set 8 | of
# City not found. Skipping...
# Processing Record 396 of Set 8 | keetmanshoop
# Processing Record 397 of Set 8 | saharsa
# Processing Record 398 of Set 8 | tura
# Processing Record 399 of Set 8 | bethanien
# Processing Record 400 of Set 8 | buon me thuot
# City not found. Skipping...
# Processing Record 401 of Set 8 | hasaki
# Processing Record 402 of Set 8 | boffa
# Processing Record 403 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 404 of Set 8 | maunabo
# Processing Record 405 of Set 8 | paris
# Processing Record 406 of Set 8 | mendoza
# Processing Record 407 of Set 8 | ha tinh
# Processing Record 409 of Set 9 | ayan
# Processing Record 410 of Set 9 | saint-pierre
# Processing Record 411 of Set 9 | churapcha
# Processing Record 412 of Set 9 | sao marcos
# Processing Record 413 of Set 9 | pierre
# Processing Record 414 of Set 9 | yuncheng
# Processing Record 415 of Set 9 | papara
# Processing Record 416 of Set 9 | conceicao do araguaia
# Processing Record 417 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 418 of Set 9 | conselheiro pena
# Processing Record 419 of Set 9 | blythe
# Processing Record 420 of Set 9 | baryatino
# Processing Record 421 of Set 9 | haines junction
# Processing Record 422 of Set 9 | bathsheba
# Processing Record 423 of Set 9 | olafsvik
# Processing Record 424 of Set 9 | bom jesus
# Processing Record 425 of Set 9 | southend-on-sea
# Processing Record 426 of Set 9 | ha giang
# Processing Record 427 of Set 9 | zalantun
# Processing Record 428 of Set 9 | morgan city
# Processing Record 429 of Set 9 | belle fourche
# Processing Record 430 of Set 9 | broken hill
# Processing Record 431 of Set 9 | magadan
# Processing Record 432 of Set 9 | upernavik
# Processing Record 433 of Set 9 | marsaxlokk
# Processing Record 434 of Set 9 | mahajanga
# Processing Record 435 of Set 9 | ketchikan
# Processing Record 436 of Set 9 | gazojak
# Processing Record 437 of Set 9 | coolum beach
# Processing Record 438 of Set 9 | kikwit
# Processing Record 439 of Set 9 | starotimoshkino
# Processing Record 440 of Set 9 | masuguru
# Processing Record 441 of Set 9 | muros
# Processing Record 442 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 443 of Set 9 | puerto maldonado
# Processing Record 444 of Set 9 | half moon bay
# Processing Record 445 of Set 9 | owen sound
# Processing Record 446 of Set 9 | skjervoy
# Processing Record 447 of Set 9 | tatawin
# Processing Record 448 of Set 9 | nogent-le-rotrou
# Processing Record 449 of Set 9 | plouzane
# Processing Record 450 of Set 9 | oskarshamn
# Processing Record 451 of Set 9 | qui nhon
# Processing Record 452 of Set 9 | roald
# Processing Record 453 of Set 9 | hovd
# Processing Record 454 of Set 9 | yialos
# City not found. Skipping...
# Processing Record 455 of Set 9 | lebork
# Processing Record 456 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 457 of Set 9 | raga
# Processing Record 458 of Set 9 | belmonte
# Processing Record 460 of Set 10 | gedzhukh
# Processing Record 461 of Set 10 | vestmannaeyjar
# Processing Record 462 of Set 10 | bahia honda
# Processing Record 463 of Set 10 | asgardstrand
# Processing Record 464 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 465 of Set 10 | impfondo
# Processing Record 466 of Set 10 | kinablangan
# Processing Record 467 of Set 10 | yar-sale
# Processing Record 468 of Set 10 | sioux lookout
# Processing Record 469 of Set 10 | havoysund
# Processing Record 470 of Set 10 | hvide sande
# Processing Record 471 of Set 10 | sao joao da barra
# Processing Record 472 of Set 10 | mawlaik
# Processing Record 473 of Set 10 | ciupercenii noi
# Processing Record 474 of Set 10 | vardo
# Processing Record 475 of Set 10 | arrecife
# Processing Record 476 of Set 10 | byumba
# Processing Record 477 of Set 10 | awjilah
# Processing Record 478 of Set 10 | mongu
# Processing Record 479 of Set 10 | ossora
# Processing Record 480 of Set 10 | goya
# Processing Record 481 of Set 10 | curvelo
# Processing Record 482 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 483 of Set 10 | lensk
# Processing Record 484 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 485 of Set 10 | maldonado
# Processing Record 486 of Set 10 | tallahassee
# Processing Record 487 of Set 10 | yulara
# Processing Record 488 of Set 10 | vagur
# Processing Record 489 of Set 10 | pontal do parana
# Processing Record 490 of Set 10 | pennagaram
# Processing Record 491 of Set 10 | paita
# Processing Record 492 of Set 10 | sayyan
# Processing Record 493 of Set 10 | varzea da palma
# Processing Record 494 of Set 10 | pitimbu
# Processing Record 495 of Set 10 | rovnoye
# Processing Record 496 of Set 10 | rangapara
# Processing Record 497 of Set 10 | arlit
# Processing Record 498 of Set 10 | meulaboh
# Processing Record 499 of Set 10 | taltal
# Processing Record 500 of Set 10 | neuquen
# Processing Record 501 of Set 10 | obo
# Processing Record 502 of Set 10 | naryan-mar
# Processing Record 503 of Set 10 | esperance
# Processing Record 504 of Set 10 | westport
# Processing Record 505 of Set 10 | pilar
# Processing Record 506 of Set 10 | biloela
# Processing Record 507 of Set 10 | rudnichnyy
# Processing Record 508 of Set 10 | san lorenzo
# Processing Record 509 of Set 10 | iisalmi
# Processing Record 511 of Set 11 | talara
# Processing Record 512 of Set 11 | yerkoy
# Processing Record 513 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 514 of Set 11 | kirksville
# Processing Record 515 of Set 11 | iqaluit
# Processing Record 516 of Set 11 | conceicao da barra
# Processing Record 517 of Set 11 | havre-saint-pierre
# Processing Record 518 of Set 11 | lawang
# Processing Record 519 of Set 11 | litovko
# Processing Record 520 of Set 11 | togur
# Processing Record 521 of Set 11 | russell
# Processing Record 522 of Set 11 | ust-kuyga
# Processing Record 523 of Set 11 | robinson
# Processing Record 524 of Set 11 | san quintin
# Processing Record 525 of Set 11 | high level
# Processing Record 526 of Set 11 | santa luzia
# Processing Record 527 of Set 11 | bereda
# Processing Record 528 of Set 11 | port moresby
# Processing Record 529 of Set 11 | belsand
# Processing Record 530 of Set 11 | emerald
# Processing Record 531 of Set 11 | omsukchan
# Processing Record 532 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 533 of Set 11 | qarqin
# Processing Record 534 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 535 of Set 11 | ixtapa
# Processing Record 536 of Set 11 | ninghai
# Processing Record 537 of Set 11 | teknaf
# Processing Record 538 of Set 11 | conde
# Processing Record 539 of Set 11 | caravelas
# Processing Record 540 of Set 11 | nioro
# Processing Record 541 of Set 11 | zabaykalsk
# Processing Record 542 of Set 11 | bilma
# Processing Record 543 of Set 11 | stornoway
# Processing Record 544 of Set 11 | los llanos de aridane
# Processing Record 545 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 546 of Set 11 | satipo
# Processing Record 547 of Set 11 | praia
# Processing Record 548 of Set 11 | scottsbluff
# Processing Record 549 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 550 of Set 11 | platanos
# Processing Record 551 of Set 11 | olinda
# Processing Record 552 of Set 11 | masterton
# Processing Record 553 of Set 11 | karatau
# Processing Record 554 of Set 11 | kumbo
# Processing Record 555 of Set 11 | dzhebariki-khaya
# Processing Record 556 of Set 11 | zlitan
# Processing Record 557 of Set 11 | tezu
# Processing Record 558 of Set 11 | price
# Processing Record 559 of Set 11 | wencheng
# Processing Record 560 of Set 11 | west wendover
# Processing Record 562 of Set 12 | emmett
# Processing Record 563 of Set 12 | shimoda
# Processing Record 564 of Set 12 | hohhot
# Processing Record 565 of Set 12 | innellan
# Processing Record 566 of Set 12 | esterhazy
# Processing Record 567 of Set 12 | vostok
# Processing Record 568 of Set 12 | geraldton
# Processing Record 569 of Set 12 | yerbogachen
# Processing Record 570 of Set 12 | sao joao do piaui
# Processing Record 571 of Set 12 | bengkulu
# Processing Record 572 of Set 12 | pedernales
# Processing Record 573 of Set 12 | turukhansk
# Processing Record 574 of Set 12 | manuk mangkaw
# Processing Record 575 of Set 12 | college
# Processing Record 576 of Set 12 | usinsk
# Processing Record 577 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 578 of Set 12 | carndonagh
# Processing Record 579 of Set 12 | bolotnoye
# Processing Record 580 of Set 12 | waingapu
# Processing Record 581 of Set 12 | sur
# Processing Record 582 of Set 12 | ghanzi
# Processing Record 583 of Set 12 | clayton
# Processing Record 584 of Set 12 | bahia blanca
# Processing Record 585 of Set 12 | santa maria
# Processing Record 586 of Set 12 | homer
# Processing Record 587 of Set 12 | nishihara
# Processing Record 588 of Set 12 | bandarbeyla
# Processing Record 589 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 590 of Set 12 | ivanovka
# Processing Record 591 of Set 12 | udachnyy
# Processing Record 592 of Set 12 | welver
# Processing Record 593 of Set 12 | sabirabad
# Processing Record 594 of Set 12 | ivanava
# Processing Record 595 of Set 12 | tyler
# Processing Record 596 of Set 12 | beyneu
# Processing Record 597 of Set 12 | maniitsoq
# Processing Record 598 of Set 12 | kholodnyy
# Processing Record 599 of Set 12 | coleraine
# Processing Record 600 of Set 12 | taonan
# Processing Record 601 of Set 12 | rovaniemi
# Processing Record 602 of Set 12 | zeya
# Processing Record 603 of Set 12 | leh
# Processing Record 604 of Set 12 | stephenville
# Processing Record 605 of Set 12 | ialibu
# Processing Record 606 of Set 12 | maralal
# Processing Record 607 of Set 12 | bintulu
# Processing Record 608 of Set 12 | poso
# Processing Record 609 of Set 12 | springbok
# Processing Record 610 of Set 12 | tres arroyos
# Processing Record 611 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 613 of Set 13 | vikulovo
# Processing Record 614 of Set 13 | pavlogradka
# Processing Record 615 of Set 13 | ariquemes
# Processing Record 616 of Set 13 | colares
# Processing Record 617 of Set 13 | altay
# Processing Record 618 of Set 13 | mezen
# Processing Record 619 of Set 13 | dunmore east
# Processing Record 620 of Set 13 | mayor pablo lagerenza
# Processing Record 621 of Set 13 | comodoro rivadavia
# Processing Record 622 of Set 13 | marsa matruh
# Processing Record 623 of Set 13 | christchurch
# Processing Record 624 of Set 13 | port hedland
# Processing Record 625 of Set 13 | yenotayevka
# Processing Record 626 of Set 13 | miro khan
# Processing Record 627 of Set 13 | lamar
# Processing Record 628 of Set 13 | road town
# Processing Record 629 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 630 of Set 13 | abu kamal
# Processing Record 631 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 632 of Set 13 | mount gambier
# Processing Record 633 of Set 13 | huntsville
# Processing Record 634 of Set 13 | vao
# Processing Record 635 of Set 13 | coahuayana
# Processing Record 636 of Set 13 | lengshuitan
# Processing Record 637 of Set 13 | beloha
# Processing Record 638 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 639 of Set 13 | krasnoye
# Processing Record 640 of Set 13 | sug-aksy
# City not found. Skipping...
# Processing Record 641 of Set 13 | kazachinskoye
# Processing Record 642 of Set 13 | black river
# Processing Record 643 of Set 13 | morehead
# Processing Record 644 of Set 13 | marquette
# Processing Record 645 of Set 13 | kayes
# Processing Record 646 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 647 of Set 13 | panelas
# Processing Record 648 of Set 13 | marawi
# Processing Record 649 of Set 13 | payo
# Processing Record 650 of Set 13 | vila
# Processing Record 651 of Set 13 | marienburg
# Processing Record 652 of Set 13 | kudahuvadhoo
# Processing Record 653 of Set 13 | marfino
# Processing Record 654 of Set 13 | jacmel
# Processing Record 655 of Set 13 | xai-xai
# Processing Record 656 of Set 13 | san policarpo
# Processing Record 657 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 658 of Set 13 | taybad
# Processing Record 659 of Set 13 | harper
# Processing Record 660 of Set 13 | nehe
# Processing Record 661 of Set 13 | mecca
# Processing Record 662 of Set 13 | sile
# Processing Record 664 of Set 14 | vysokogornyy
# Processing Record 665 of Set 14 | darnah
# Processing Record 666 of Set 14 | timizart
# Processing Record 667 of Set 14 | matay
# Processing Record 668 of Set 14 | ambagarh chauki
# Processing Record 669 of Set 14 | luebo
# Processing Record 670 of Set 14 | methoni
# Processing Record 671 of Set 14 | alvinopolis
# Processing Record 672 of Set 14 | bogorodskoye
# Processing Record 673 of Set 14 | sangar
# Processing Record 674 of Set 14 | rorvik
# Processing Record 675 of Set 14 | gaptsakh
# Processing Record 676 of Set 14 | abu zabad
# Processing Record 677 of Set 14 | makakilo city
# Processing Record 678 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 679 of Set 14 | hambantota
# Processing Record 680 of Set 14 | belmopan
# Processing Record 681 of Set 14 | springdale
# Processing Record 682 of Set 14 | yashkul
# Processing Record 683 of Set 14 | san rafael
# Processing Record 684 of Set 14 | tambovka
# Processing Record 685 of Set 14 | gobabis
# Processing Record 686 of Set 14 | umba
# Processing Record 687 of Set 14 | griffith
# Processing Record 688 of Set 14 | pacific grove
# Processing Record 689 of Set 14 | ancud
# Processing Record 690 of Set 14 | karera
# Processing Record 691 of Set 14 | gornyy
# Processing Record 692 of Set 14 | henties bay
# Processing Record 693 of Set 14 | bonoua
# Processing Record 694 of Set 14 | codrington
# Processing Record 695 of Set 14 | beringovskiy
# Processing Record 696 of Set 14 | safakulevo
# Processing Record 697 of Set 14 | kirriemuir
# Processing Record 698 of Set 14 | sicuani
# Processing Record 699 of Set 14 | baykit
# Processing Record 700 of Set 14 | banda aceh
# Processing Record 701 of Set 14 | joaima
# Processing Record 702 of Set 14 | warrington
# Processing Record 703 of Set 14 | kemijarvi
# Processing Record 704 of Set 14 | auki
# Processing Record 705 of Set 14 | mersing
# Processing Record 706 of Set 14 | galveston
# Processing Record 707 of Set 14 | luancheng
# Processing Record 708 of Set 14 | aripuana
# Processing Record 709 of Set 14 | culiacan
# Processing Record 710 of Set 14 | bontang
# Processing Record 711 of Set 14 | severo-yeniseyskiy
# Processing Record 712 of Set 14 | maltahohe
# Processing Record 713 of Set 14 | cockburn town
# Processing Record 715 of Set 15 | champerico
# Processing Record 716 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 717 of Set 15 | kindu
# Processing Record 718 of Set 15 | vazante
# Processing Record 719 of Set 15 | onega
# Processing Record 720 of Set 15 | chimbote
# Processing Record 721 of Set 15 | lagodekhi
# Processing Record 722 of Set 15 | grass valley
# Processing Record 723 of Set 15 | teahupoo
# Processing Record 724 of Set 15 | kathmandu
# Processing Record 725 of Set 15 | tadine
# Processing Record 726 of Set 15 | mega
# Processing Record 727 of Set 15 | pervomayskoye
# Processing Record 728 of Set 15 | moradabad
# Processing Record 729 of Set 15 | thanh hoa
# Processing Record 730 of Set 15 | ugoofaaru
# Processing Record 731 of Set 15 | elizabeth city
# Processing Record 732 of Set 15 | anadyr
# Processing Record 733 of Set 15 | corund
# Processing Record 734 of Set 15 | bubaque
# Processing Record 735 of Set 15 | hurghada
# Processing Record 736 of Set 15 | joensuu
# Processing Record 737 of Set 15 | ranfurly
# Processing Record 738 of Set 15 | monastyrshchina
# Processing Record 739 of Set 15 | kargasok
# Processing Record 740 of Set 15 | noyabrsk
# Processing Record 741 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 742 of Set 15 | biankouma
# Processing Record 743 of Set 15 | north bend
# Processing Record 744 of Set 15 | kodinsk
# Processing Record 745 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 746 of Set 15 | lakeside
# Processing Record 747 of Set 15 | na klang
# Processing Record 748 of Set 15 | labuan
# Processing Record 749 of Set 15 | sampit
# Processing Record 750 of Set 15 | erzin
# Processing Record 751 of Set 15 | manta
# Processing Record 752 of Set 15 | pavlovka
# Processing Record 753 of Set 15 | kuandian
# Processing Record 754 of Set 15 | aykhal
# Processing Record 755 of Set 15 | sabha
# Processing Record 756 of Set 15 | sibolga
# Processing Record 757 of Set 15 | buala
# Processing Record 758 of Set 15 | bartica
# Processing Record 759 of Set 15 | manono
# Processing Record 760 of Set 15 | darhan
# Processing Record 761 of Set 15 | andros town
# Processing Record 762 of Set 15 | oparino
# Processing Record 763 of Set 15 | micheweni
# Processing Record 764 of Set 15 | shizunai
# Processing Record 766 of Set 16 | karratha
# Processing Record 767 of Set 16 | coffs harbour
# Processing Record 768 of Set 16 | galiwinku
# City not found. Skipping...
# ***Data Retrieval Is Complete***

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kaa-Khem  51.6833   94.7333     67.17        55           3
# 1       Abu Samrah  35.3029   37.1841     77.02        58           0
# 2           Faanui -16.4833 -151.7500     78.96        66           6
# 3            Lagoa  39.0500  -27.9833     72.90        82           7
# 4        Busselton -33.6500  115.3333     54.88        79         100
# ..             ...      ...       ...       ...       ...         ...
# 692        Oparino  59.8518   48.2783     60.26        62          29
# 693      Micheweni  -4.9667   39.8333     73.67        84          20
# 694       Shizunai  42.3339  142.3669     66.16        65         100
# 695       Karratha -20.7377  116.8463     70.07        23           0
# 696  Coffs Harbour -30.3000  153.1333     64.36        89          75
#
#      Wind Speed       Description
# 0          2.13         clear sky
# 1          6.38         clear sky
# 2         14.14         clear sky
# 3         17.60         clear sky
# 4          5.91   overcast clouds
# ..          ...               ...
# 692        8.79  scattered clouds
# 693       10.29        few clouds
# 694       11.03   overcast clouds
# 695       17.05         clear sky
# 696        5.75     broken clouds
#
# [697 rows x 8 columns]

# %%
# save to csv
city_data_df.to_csv("/Users/michaelmanthey/Documents/Bootcamp/Module_6_Python_APIs/Challenge/Weather_Database/weather_data.csv")
